# %% [markdown]
# # Kapselguide – XMAX V3 Pro (energisk high)

# %% [markdown]
# ---
# ## 🌿 Kapselguide
#
# ### 1. Forbered urten
#
# - Mal urten **mellemfin** (ikke støv, men heller ikke grove stykker).
# - Den skal være **let sprød** – ikke fugtig, men heller ikke knastør.
#   - For fugtig → mindre damp.
#   - For tør → harsk smag og hurtigere opvarmning.
#
# ### 2. Fyld kapslen korrekt
#
# - Fyld **50–70 %** – næsten fuld, men uden at presse.
# - Jævn let overfladen med en fingerspids eller værktøj.
# - Sørg for, at luften stadig kan passere gennem urten.
#
# ### 3. Temperatur
#
# - Start ved **180 °C** og øg evt. til **185–190 °C** senere.
# - Undgå at overstige **190 °C**, da det kan give tung, sedativ virkning.
# - Brug gerne **+5–10 °C højere end normalt**, da kapslen absorberer varme.
#
# ### 4. Forvarmning
#
# - Vent **10–25 sekunder** efter at enheden siger “klar”.
#   - Dette opvarmer også selve kapslen.
# - Tag evt. ét svagt sug først for at varme luften op i kapslen.
#
# ### 5. Sug og sessionsteknik
#
# - Sug **langsomt og roligt i 6–10 sekunder**.
#   - Forestil dig, at du langsomt drikker varm te gennem sugerør.
# - For hurtige sug → kammeret køles ned, og dampen bliver tynd.
# - Efter **3–4 sug** → ryst kapslen let.
# - Mod slutningen → evt. hæv temperaturen **+5 °C** for at tømme urten.

# %% [markdown]
# ---
# ## ⚙️ Hurtig opskrift
#
# | Trin | Handling                  | Noter                                      |
# |------|---------------------------|---------------------------------------------|
# | 1    | Fyld 50–70 %              | Luft skal kunne cirkulere                   |
# | 2    | Temp: +5–10 °C            | Fx 180 → 185–190 °C                         |
# | 3    | Forvarm 10–25 sek         | Efter "klar"-signal                         |
# | 4    | Sug langsomt (6–10 sek)   | Jævn damp, bedre effekt                     |
# | 5    | Ryst efter 3.–4. sug      | Ensartet varmefordeling                     |
# | 6    | Rens efter brug           | Bevar smag og effektivitet                  |

# %% [markdown]
# ---
# ## 🔹 Eksempel-session (energisk fokus)
#
# | Trin | Temperatur | Sug (sek) | Handling                                         |
# |------|------------|-----------|--------------------------------------------------|
# | 1    | 180 °C     | 3–5       | 1. sug – aromatisk start                         |
# | 2    | 180 °C     | 3–5       | 2. sug – THC begynder at virke                   |
# | 3    | 180 °C     | 3–5       | 3. sug – psykedelisk klarhed                     |
# | —    | —          | —         | Ryst kapslen 2–3 gange                           |
# | 4    | 185 °C     | 3–5       | 4. sug – kropslig energi + mental fokus          |
# | 5    | 185 °C     | 3–5       | 5. sug – peak-effekt                             |
# | 6    | 185 °C     | 3–5       | 6. sug – blød afrunding                          |
# | Valgfri | 190 °C  | 2–3       | Slut-sug – kun for at tømme helt (kan give tunghed) |

# %% [markdown]
# ---
# ## 🔹 Tidslinje (fra “klar”-øjeblikket)
#
# | Tid     | Temp     | Handling              | Effekt / Kommentar                         |
# |---------|----------|------------------------|---------------------------------------------|
# | 0:00    | 180 °C   | Enhed viser “klar”     | —                                           |
# | 0:00–0:25 | 180 °C | Vent 20–25 sek         | Urten opvarmes til reel temperatur          |
# | 0:25    | 180 °C   | 1. sug                 | Aromatisk damp, THC begynder at virke       |
# | 0:45    | 180 °C   | 2. sug                 | Fyldigere damp, kropsvarme                  |
# | 1:05    | 180 °C   | 3. sug                 | Psykedelisk klarhed                         |
# | 1:25    | —        | Ryst kapslen           | Jævn varmefordeling                         |
# | 1:40    | 185 °C   | 4. sug                 | Mental fokus + kropslig energi              |
# | 2:00    | 185 °C   | 5. sug                 | Balanceret high                             |
# | 2:20    | 185 °C   | 6. sug                 | Blød afrunding                              |
# | 2:40+   | 190 °C   | Slut-sug               | Valgfrit – kan give lidt tunghed            |

# %% [markdown]
# ---
# ## 🧠 Effektprofil over tid
#
# | Tid             | Effektprofil                                      |
# |------------------|---------------------------------------------------|
# | 0–0:30 min       | Forvarmning → urten stabiliseres                 |
# | 0:30–1:30 min    | Opbygning → aromatisk, let eufori                |
# | 1:30–2:30 min    | Peak → psykedelisk klarhed, kropslig varme       |
# | 2:30–3:00 min    | Afrunding → blød, fokuseret efterglød            |
#
# **Effektniveauer:**
#
# - Klarhed ↑↑↑↑
# - Energi ↑↑↑
# - Kropslig ↑↑
# - Tunghed ↓

# %% [markdown]
# ---
# ## 🌡️ Temperatur og cannabinoider
#
# | Temperatur | Cannabinoider                                 | Effekt                                                  |
# |------------|-----------------------------------------------|---------------------------------------------------------|
# | 160 °C     | THC-A, CBD-A, CBG-A (delvis)                 | Let aromatisk high, meget lidt tunghed                 |
# | 170 °C     | THC, CBD, CBG                                 | Klar, energisk mental effekt                           |
# | 180 °C     | THC (mere aktiveret), CBD, CBG, CBN (begyndende) | Balanceret high med energi                        |
# | 185 °C     | THC, CBD, CBG, CBN (mere)                    | Kropslig varme uden stoner-effekt                      |
# | 190 °C     | THC (fuldt), CBN øges                        | Mere kropslig, begynder at tynge                       |
# | 200 °C     | THC reduceres, CBN høj                       | Stoner-effekt, tunghed, harsk smag                     |

# %% [markdown]
# ---
# ## 🧪 Effektprofil for cannabinoider
#
# | Stof      | Virkning                                                   |
# |-----------|------------------------------------------------------------|
# | CBG       | Energisk, fokuseret, støtter THC uden tunghed              |
# | THC       | Psykedelisk high, eufori, mental klarhed                   |
# | CBD       | Afbalancerer THC, rolig krop, dæmper angst                 |
# | CBN       | Tunghed, søvnighed, stoner-effekt                          |
# | Terpener  | Aroma, smag, subtil stemningspåvirkning                    |
#
# 💡 CBG frigives ved samme temperatur som THC, men giver ikke tunghed.
# Derfor er **180–190 °C ideelt** for en **energisk og klar rus**.

# %% [markdown]
# ---
# ## ✅ Afsluttende anbefalinger
#
# | Parameter                | Anbefaling                  |
# |--------------------------|-----------------------------|
# | Fyldning                 | 50–70 % (løst pakket)        |
# | Temperatur               | 180 °C → 185 °C (max 190 °C) |
# | Sugelængde               | 6–10 sek (langsomt)          |
# | Pause mellem sug         | 20 sek                       |
# | Forvarmning efter “klar” | 20–25 sek                    |
# | Rystetidspunkt           | Efter 3. sug                 |
# | Samlet sessionstid       | 3–3½ minutter                |
